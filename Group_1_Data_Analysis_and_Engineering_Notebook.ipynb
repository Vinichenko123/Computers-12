# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinichenko123/Computers-12/blob/main/Group_1_Data_Analysis_and_Engineering_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Github link, you can use "save copy in github" in Files for commits
# If you just joined, I've sent you an invite to the github through the same email that you're using for google colab
# ```
# https://github.com/Vinichenko123/Group1-Data-Preprocessing.git
# ```

# %% [markdown]
# import pandas

# %%
import pandas as pd
import numpy as np
import graphviz

# %% [markdown]
# import the data, change numerical data that represents categories to string
# - might want to change the index to the "unnamed" column, but need to give it a name
# - need to abbriave more columns and select more categorical numerical data

# %%
#data = pd.read_csv('dataset-converted.csv', index_col='Client_ID', dtype={ 'PI_Job_Seeker_Supports': str, 'Outcome_Return_to_Work' : str, 'Education_Completion_Year' : str,  })
#data

data = pd.read_csv('dataset-converted.csv', index_col='Client_ID')

data.rename(columns={
    'PI_Job_Seeker_Supports': 'PISupport',
    'Outcome_Return_to_Work': 'OutcomeWork',
    'Education_Completion_Year': 'EduYear'
}, inplace=True)

# Convert numeric columns representing categorical data to string
data[['PISupport', 'OutcomeWork','EduYear']] = data[['PISupport', 'OutcomeWork','EduYear']].astype(str)

data
# Out:
#            Unnamed: 0  Birth Date   Age         City Province  \
# Client_ID
# 100001.0          0.0  1998-01-23  26.0      Toronto       ON
# 100002.0          1.0  1960-09-16  63.0      Halifax       NS
# 100003.0          2.0  1977-03-11  46.0      St.John       NL
# 100004.0          3.0  1969-10-17  54.0  Quebec City       QC
# 100005.0          4.0  1972-05-01  51.0      Calgary       AB
# ...               ...         ...   ...          ...      ...
# 100100.0         99.0  1959-12-11  64.0      Calgary       AB
# NaN               NaN         NaN   NaN          NaN      NaN
# NaN               NaN         NaN   NaN          NaN      NaN
# NaN               NaN         NaN   NaN          NaN      NaN
# NaN               NaN         NaN   NaN          NaN      NaN
#
#           Preferred_Language   Birth_Country Year_of_Arrival_to_Canada  \
# Client_ID
# 100001.0              French          Canada            Not applicable
# ...

# %% [markdown]
# install spacy if not already installed

# %%
import subprocess
import sys
# if spacy isn't already installed, install it
if 'spacy_installed' not in globals():
    subprocess.check_call([sys.executable, "-m", "pip", "install", "https://github.com/explosion/spacy-models/releases/download/en_trf_xlnetbasecased_lg-2.2.0/en_trf_xlnetbasecased_lg-2.2.0.tar.gz"])
    subprocess.check_call([sys.executable, "-m", "pip", "install", "--upgrade", "spacy"])

    spacy_installed = True
